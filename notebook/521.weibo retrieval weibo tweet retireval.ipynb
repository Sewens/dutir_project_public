# %% [markdown]
# # 将检索模块和文本聚类模块进行封装

# %%
import time
import random
import os
import re
import pandas as pd
import numpy as np
from datetime import datetime
from elasticsearch import Elasticsearch

# %%
import mysql.connector

# %% [markdown]
# # ES检索模块重构为一个对象

# %%
class esWeiboTweetRetrieval():
    '''
    根据论文检索需求进行功能的微调
    '''
    _instance = None
    _first_init = True
    def __new__(cls, *args, **kw):
        if not cls._instance:
            cls._instance = super(esWeiboTweetRetrieval, cls).__new__(cls)  
        return cls._instance
    
    def __init__(self, host, port):
        '''
        使用ES进行论文检索 指定host、port以及专利index之后进行检索
        '''
        super(esWeiboTweetRetrieval, self).__init__()
        self.es = Elasticsearch(hosts=host, port=port, timeout=30, max_retries=10, retry_on_timeout=True)
        self.indexName = 'weibo-tweet-index'

    def do_search(self, W_search_query, W_content, volume):
        '''
        do_search方法执行具体检索过程
        wordQuery 本应为查询对应微博时所用的检索词 此处暂时不用 目前暂时只检索微博评论数据后续再修改对象为
        
        volume为每次检索返回的数目
        '''
        queryBody = {
        "query": {
        "bool": {
        "must": [ ],
        "must_not": [ ],
        "should": [
        {
        "query_string": {
        "default_field": "W_content",
        "query": W_content
        }
        }
        ,
        {
        "query_string": {
        "default_field": "W_search_query",
        "query": W_search_query
        }
        }
        ]
        }
        },
        "from": 0,
        "size": volume,
        "sort": [ ],
        "aggs": { }
        }
        result = self.es.search(index=self.indexName, body=queryBody)
        return result

    def format_search(self, result):
        '''
        format_search方法对检索结果进行格式化 构建符合要求的字段进行返回
        输入result为检索结果 提取其中的检索结果进行后处理
        使用ES检索后得到的结果中result['hits']['hits']为数组格式数据
        其中每一个元素为一个dict 对应部分字段
        '''
        docs = result['hits']['hits']
        docs = [i['_source'] for i in docs]
        targetKeyList = 'W_ID,W_weibo_id,W_search_query,W_nick_name,W_weibo_url,W_created_at,\
        W_like_num,W_repost_num,W_comment_num,W_content,W_user_id,W_image_url,W_video_url,W_tool,W_location,\
        W_location_map_info,W_origin_weibo_url,W_origin_weibo_content,W_crawl_time'
        targetKeyList = [i.strip() for i in targetKeyList.split(',')]
        dict_filter_by_keys = lambda d: {k: d[k] for k in targetKeyList}
        dict_filter_id = lambda d: {k if not k == '_id' else 'id': d[k] for k in d}
        docs = list(dict_filter_by_keys(doc) for doc in docs)
        return docs
    def Retrieval(self, W_search_query, W_content, volume):
        result = self.do_search(W_search_query, W_content, volume)
        docs = self.format_search(result)
        return docs

# %%
eee = esWeiboTweetRetrieval(host='10.8.128.205',port=49200,)

# %%
result= eee.Retrieval(W_search_query='#垃圾分类#', W_content='北京',volume=100)

# %%
result
# Out:
# [{'W_ID': 521,
#   'W_weibo_id': '1606087470_AtvCJ6J0Y',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '毛达1977',
#   'W_weibo_url': 'https://weibo.com/1606087470/AtvCJ6J0Y',
#   'W_created_at': '2014-01-24T18:15:10',
#   'W_like_num': 5,
#   'W_repost_num': 400,
#   'W_comment_num': 165,
#   'W_content': '#垃圾分类# 北京市法制宣传教育领导小组办公室、北京市司法局：“不分类 环境恶化、资源浪费”，“厨余垃圾→堆肥”。很想问问：现在北京厨余垃圾多少堆肥了？效率、效果、去向如何？能不能将混合垃圾和较纯厨余分开堆肥，对比一下？@北京市市政市容委@卫潘明@张红樱@立雯nu@垃圾战斗机FON@冯永锋',
#   'W_user_id': '1606087470',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 3922,
#   'W_weibo_id': '6602407876_HzFqUCQqL',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '王希希ss',
#   'W_weibo_url': 'https://weibo.com/6602407876/HzFqUCQqL',
#   'W_created_at': '2019-06-19T21:25:00',
#   'W_like_num': 13,
#   'W_repost_num': 11,
#   'W_comment_num': 2,
#   'W_content': '#北京将立法约束垃圾分类#北京将立法明确垃圾分类个人责任，混合投放垃圾将被罚！#垃圾分类# 王希希ss的微博视频',
#   'W_user_id': '6602407876',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '隐形贫困人口',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 282,
#   'W_weibo_id': '1065190973_HAo5Cwj2q',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '济宁环境',
#   'W_weibo_url': 'https://weibo.com/1065190973/HAo5Cwj2q',
#   'W_created_at': '2019-06-24T15:06:00',
#   'W_like_num': 4,
#   'W_repost_num': 7,
#   'W_comment_num': 4,
#   'W_content': '【北京拟对垃圾不分类的个人罚款，视频科普#干湿垃圾怎么区分# [思考]】日前，北京市城市管理委主任孙新军在做客节目时透露，《北京市生活垃圾管理条例》修订工作已列入2018-2020年的立法规划，新修订的条例拟对个人明确垃圾分类责任，混合投放垃圾最高要处以200元罚款，北京也不会低于这个数。对于北京针对垃圾分类的骤然提速，很多网友非常懵：各类垃圾到底怎么分？#垃圾分类# 视频科普：http://t.cn/AipS8vSa',
#   'W_user_id': '1065190973',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'OPPO随光而变R17',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 1585,
#   'W_weibo_id': '2383997393_HBIeH11BN',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '英宠摄影inpetphoto',
#   'W_weibo_url': 'https://weibo.com/2383997393/HBIeH11BN',
#   'W_created_at': '2019-07-03T08:14:00',
#   'W_like_num': 64,
#   'W_repost_num': 32,
#   'W_comment_num': 21,
#   'W_content': '#你是个什么垃圾北京版# 一个#垃圾分类# 连续上热门得有一周了吧，还以为上海人民先替全国人民受难会坚持一年半载，没想到全国推行这么快，北京也要实施了[允悲] 关键是北京、上海标准还不一样，像我们这种一年有四个月在上海出差的人，要背两套规定啊[允悲][允悲][允悲][允悲]  #北京将推动垃圾分类立法#',
#   'W_user_id': '2383997393',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone X',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 1830,
#   'W_weibo_id': '2673559233_HBKIT5w7e',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '南昌高新区发布',
#   'W_weibo_url': 'https://weibo.com/2673559233/HBKIT5w7e',
#   'W_created_at': '2019-07-03T14:34:00',
#   'W_like_num': 12,
#   'W_repost_num': 72,
#   'W_comment_num': 29,
#   'W_content': '【[话筒]提前转存！北京将推动垃圾分类立法 分类标准与上海不完全一致】#垃圾分类# 日前，记者从北京市城管委了解到，北京将推动垃圾分类立法，罚款不低于上海。但北京的垃圾分类标准与上海并不完全一致，分为厨余垃圾、有害垃圾、其它垃圾及可回收物。具体怎么分？戳视频↓  南昌高新区发布的微博视频',
#   'W_user_id': '2673559233',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '360安全浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 2697,
#   'W_weibo_id': '5132868371_HAzwD6yyR',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '直通石家庄',
#   'W_weibo_url': 'https://weibo.com/5132868371/HAzwD6yyR',
#   'W_created_at': '2019-06-25T20:13:00',
#   'W_like_num': 0,
#   'W_repost_num': 16,
#   'W_comment_num': 4,
#   'W_content': '#垃圾分类# 上海北京步入垃圾分类强制时代，来自河北的你做好准备了吗？ [组图共2张]',
#   'W_user_id': '5132868371',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'HUAWEI P20',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 10225,
#   'W_weibo_id': '1937618377_yB7xy2ZGc',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/yB7xy2ZGc',
#   'W_created_at': '2012-09-09T22:10:19',
#   'W_like_num': 0,
#   'W_repost_num': 3,
#   'W_comment_num': 6,
#   'W_content': '来自网络评论：《北京青年》就是一个北京老年用一群北京中年来演绎空想的北京青年的故事。妙哉！',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T14:35:00'},
#  {'W_ID': 2922,
#   'W_weibo_id': '5495888715_HCtvawcfM',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '极恶的兔子',
#   'W_weibo_url': 'https://weibo.com/5495888715/HCtvawcfM',
#   'W_created_at': '2019-07-08T08:33:00',
#   'W_like_num': 14,
#   'W_repost_num': 26,
#   'W_comment_num': 15,
#   'W_content': '你是什么垃圾？ #垃圾分类# 北京 显示地图[组图共4张]',
#   'W_user_id': '5495888715',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '?️?iPhone 7',
#   'W_location': '极恶的兔子',
#   'W_location_map_info': '116.320343,39.847279',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 369,
#   'W_weibo_id': '1272741311_HBLhMEThB',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '意林杂志',
#   'W_weibo_url': 'https://weibo.com/1272741311/HBLhMEThB',
#   'W_created_at': '2019-07-03T16:00:00',
#   'W_like_num': 321,
#   'W_repost_num': 34,
#   'W_comment_num': 31,
#   'W_content': '#北京将推动垃圾分类立法# #垃圾分类# 你们分得清楚吗？[允悲]',
#   'W_user_id': '1272741311',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 2210,
#   'W_weibo_id': '3298202727_HBtD2rc9m',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '亥时热评',
#   'W_weibo_url': 'https://weibo.com/3298202727/HBtD2rc9m',
#   'W_created_at': '2019-07-01T19:02:00',
#   'W_like_num': 15,
#   'W_repost_num': 10,
#   'W_comment_num': 0,
#   'W_content': '#亥时点评#【 #垃圾分类# “逼疯”上海人？别笑！马上轮到北京】[允悲][允悲] #垃圾分类成上海新社交# #垃圾分类就是新时尚# 垃圾分类“逼疯”上海人？别笑！马上轮到北京…… 人民日报的秒拍视频',
#   'W_user_id': '3298202727',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 5865,
#   'W_weibo_id': '2152024140_FDXR8wXyz',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/FDXR8wXyz',
#   'W_created_at': '2018-01-12T06:12:07',
#   'W_like_num': 1,
#   'W_repost_num': 2,
#   'W_comment_num': 0,
#   'W_content': '//@普大喜奔流到海不复回:支持北航。@平安北京 性侵在北京是违法犯罪吗？',
#   'W_user_id': '2152024140',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/FDV3ODsk6?rl=0#cmtfrm',
#   'W_origin_weibo_content': '【处理通报】        对近期关于我校教师陈小武的实名举报和媒体的有关反映，学校本着高度负责、实事求是的态度，认真细致地开展了调查核实工作。现已查明，陈小武存在对学生的性骚扰行为。        陈小武的行为严重违背了教师的职业道德和行为规范，造成了恶劣的社会影响。根据国家和学校相关规定，经研究决定，撤销陈小武研究生院常务副院长职务，取消其研究生导师资格，撤销其教师职务，取消其教师资格。        “德才兼备、知行合一”是北航人的价值追求，学校对违反师德师风的行为始终坚持零容忍。学校将以此为鉴，制定相关实施细则，健全相关机制，进一步加强师德师风建设，努力办好人民满意的教育。',
#   'W_crawl_time': '2019-07-18T13:17:00'},
#  {'W_ID': 1903,
#   'W_weibo_id': '2775729100_HBIOTjmGO',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '严伯钧',
#   'W_weibo_url': 'https://weibo.com/2775729100/HBIOTjmGO',
#   'W_created_at': '2019-07-03T09:43:00',
#   'W_like_num': 158,
#   'W_repost_num': 41,
#   'W_comment_num': 39,
#   'W_content': '#北京将推动垃圾分类立法#据说上海人民最近被 #垃圾分类# 搞疯了，北京、杭州也快了。今天就讲讲垃圾为什么要分类？从大方向讲就是全民对垃圾系统进行能量输入以减缓熵增……  严伯钧的微博视频',
#   'W_user_id': '2775729100',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博视频',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 5246,
#   'W_weibo_id': '1744851064_B0WUQf1i4',
#   'W_search_query': ' ',
#   'W_nick_name': '1744851064',
#   'W_weibo_url': 'https://weibo.com/1744851064/B0WUQf1i4',
#   'W_created_at': '2014-04-22T21:09:26',
#   'W_like_num': 2,
#   'W_repost_num': 5,
#   'W_comment_num': 2,
#   'W_content': '北京政府真是无耻到了极点，估计过几年来北京就得签证了！！！！！',
#   'W_user_id': '1744851064',
#   'W_image_url': 'http://ww4.sinaimg.cn/wap180/0001944ctw1efofti6fg6j20mz0wa111.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/B0V8UqakJ?rl=0#cmtfrm',
#   'W_origin_weibo_content': '进京证有效期跟摄像头联网了，非高峰期的周末在二环开阳桥被拍，100元3分，外地车无进京证是没法开了。就算办了证一不小心在帝都内超期，各个办证处还必须车到才给办，岂不是就只能趁着月黑风高的夜晚遮挡车牌出京办证了；或者费点钱和分，探一条出六环安全小路。',
#   'W_crawl_time': '2019-07-18T12:44:00'},
#  {'W_ID': 4151,
#   'W_weibo_id': '2993883977_Bkdh4m3i7',
#   'W_search_query': ' ',
#   'W_nick_name': '2993883977',
#   'W_weibo_url': 'https://weibo.com/2993883977/Bkdh4m3i7',
#   'W_created_at': '2014-08-27T13:43:56',
#   'W_like_num': 11,
#   'W_repost_num': 29,
#   'W_comment_num': 5,
#   'W_content': 'ICPR2018已定在北京召开。',
#   'W_user_id': '2993883977',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '索尼Xperia Z L36h',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T16:59:00'},
#  {'W_ID': 9284,
#   'W_weibo_id': '1937618377_y08es7ZCw',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/y08es7ZCw',
#   'W_created_at': '2012-01-10T15:54:47',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '鼓励大家都上微博，有事好照应。多转！ //@finallyly:// @王斌_ICTIR : 转！// @梁斌penny : 火车票打个微博帐号就方便了。// @cliz :// @平安北京 :  #暖冬北京#  这节骨眼儿上丢车票，失主该多着急啊！！转起来！！！谢谢咱562路的乘务员~[赞]  @北京铁路   @北京站官方微博',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/y0597pcXV?rl=0#cmtfrm',
#   'W_origin_weibo_content': '【请大家帮忙转发急寻失主】1月8日晚21点左右，562路44181号车回到党校北门终点站后，乘务员穆向贞在打扫卫生时发现一张火车票遗落在车厢内。车票为1月19日北京到鞍山的K95次列车，车票失主叫葛琳琳，562路车队正焦急地等待失主前来认领。请失主及时与562路车队联系，电话：62808700。[织]',
#   'W_crawl_time': '2019-07-16T13:15:00'},
#  {'W_ID': 5248,
#   'W_weibo_id': '1744851064_B1p1O3MJK',
#   'W_search_query': ' ',
#   'W_nick_name': '1744851064',
#   'W_weibo_url': 'https://weibo.com/1744851064/B1p1O3MJK',
#   'W_created_at': '2014-04-25T20:43:31',
#   'W_like_num': 1,
#   'W_repost_num': 0,
#   'W_comment_num': 2,
#   'W_content': '北京这么好的政策必须抓紧效仿啊，希望全国城市都尽快设立进城证，向北京学习！',
#   'W_user_id': '1744851064',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/B1oRc1cPF?rl=0#cmtfrm',
#   'W_origin_weibo_content': '河北石家庄下周办理外地车进二环通行证，早晚高峰期禁止外地牌照车进入二环，这是长年的北京受气包的小逆袭[嘻嘻] 京石通婚的很多，无一例外都在京购车上牌，京牌车在石家庄横趟，而冀牌车进京要办证受限，现在“双向限”替代“单向限”，有点平等了。[哈哈]',
#   'W_crawl_time': '2019-07-18T12:44:00'},
#  {'W_ID': 8613,
#   'W_weibo_id': '1937618377_nJxbag',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/nJxbag',
#   'W_created_at': '2011-07-18T18:18:12',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '北京成为沿海城市，南京不甘落后，南北呼应，遍地泽国。地理书是否需要修改一下？//@黄健翔：我们南京终于变成沿海城市了？',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/nJm6zQ?rl=0#cmtfrm',
#   'W_origin_weibo_content': '【微博直播看海】北京、武汉没海了，不要紧，现在南京又有了！今天中午，南京城再次接受暴雨洗礼，组图直播看大海，很鸡冻，有木有！（图片来自微博网友）',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 1355,
#   'W_weibo_id': '2076169303_HBs5MrGW4',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '圈扒菌',
#   'W_weibo_url': 'https://weibo.com/2076169303/HBs5MrGW4',
#   'W_created_at': '2019-07-01T15:08:00',
#   'W_like_num': 295,
#   'W_repost_num': 160,
#   'W_comment_num': 196,
#   'W_content': '#垃圾分类 卡路里#闻圾起舞寓教于乐[给力] 北京人民也在瑟瑟发抖[允悲][允悲][允悲]谈小培在旅途的秒拍视频',
#   'W_user_id': '2076169303',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 1917,
#   'W_weibo_id': '2789616391_HCXMW25q6',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': 'CCTV6电影频道',
#   'W_weibo_url': 'https://weibo.com/2789616391/HCXMW25q6',
#   'W_created_at': '2019-07-11T13:40:00',
#   'W_like_num': 26,
#   'W_repost_num': 4,
#   'W_comment_num': 8,
#   'W_content': '北京马上也要推行#垃圾分类# 了，你的城市准备好了吗？还没准备好的戳进来，了解一下吧！ M视频News的微博视频',
#   'W_user_id': '2789616391',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 10832,
#   'W_weibo_id': '1937618377_A5YtJglms',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/A5YtJglms',
#   'W_created_at': '2013-08-22T23:35:22',
#   'W_like_num': 0,
#   'W_repost_num': 2,
#   'W_comment_num': 2,
#   'W_content': '小时候经常唱＂我爱北京天安门＂，渴望到北京。时光穿越几十年，来了北京却不容易离开，飞机总是恋恋不舍，又晚点了，是让我带着首都的情谊去迎接大连海边的黎明⋯',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T15:36:00'},
#  {'W_ID': 3052,
#   'W_weibo_id': '5648905385_HAxtstbM1',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '文明通州',
#   'W_weibo_url': 'https://weibo.com/5648905385/HAxtstbM1',
#   'W_created_at': '2019-06-25T15:00:00',
#   'W_like_num': 6,
#   'W_repost_num': 10,
#   'W_comment_num': 12,
#   'W_content': '#不忘初心 牢记使命#【生活垃圾分类制度将入法】#你好，副中心#固体废物污染环境防治法修订草案25日初次提请全国人大常委会审议。草案对“生活垃圾污染环境的防治”进行了专章规定。草案提出，国家推行生活#垃圾分类#制度。县级以上地方人民政府应当采取符合本地实际的分类方式，加快建立生活垃圾分类投放、分类收集、分类运输、分类处理的垃圾处理系统，实现垃圾分类制度有效覆盖。@新华视点@中国长安网@北京通州发布@带你看通州@北青社区报通州版@法晚通州社区@北京同城@北京市城市管理委员会',
#   'W_user_id': '5648905385',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 3254,
#   'W_weibo_id': '5872828878_HDLP1iHVR',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '内蒙古反邪教',
#   'W_weibo_url': 'https://weibo.com/5872828878/HDLP1iHVR',
#   'W_created_at': '2019-07-16T21:02:00',
#   'W_like_num': 11,
#   'W_repost_num': 10,
#   'W_comment_num': 11,
#   'W_content': '【#清华公布在京本科提档线# 理科680分、文科668分】北京教育考试院公布2019年北京市高招本科普通提档线。各大在京重点高校分数线出炉。这也是一本二本合并之后，各大高校在京本科普通批提档线首次出炉。今年，清华在京本科一批次录取分数线理科680分，文科668分，全部位居在京招生全国高校之首。http://t.cn/AiWBoMdm（北京日报）',
#   'W_user_id': '5872828878',
#   'W_image_url': 'http://wx3.sinaimg.cn/wap180/006prN4qly1g51zc71aj3j30u038wax2.jpg',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T09:07:00'},
#  {'W_ID': 3133,
#   'W_weibo_id': '5726009017_HBrUGyVNp',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': 'DT财经',
#   'W_weibo_url': 'https://weibo.com/5726009017/HBrUGyVNp',
#   'W_created_at': '2019-07-01T14:40:00',
#   'W_like_num': 4,
#   'W_repost_num': 13,
#   'W_comment_num': 1,
#   'W_content': 'http://t.cn/Ai0SCtdm 2017年北京生活垃圾清运量为924.77万吨，如果用载重5吨的卡车来运送，两辆一排，可以从云南西双版纳排到哈尔滨。目前我国城市垃圾处理最主要的方式是填埋与焚烧，但都存在一定的弊端，假设北京的生活#垃圾分类# 妥善，每年因垃圾致癌的人数将从241人降低至182人。@第一财经日报 [组图共5张]',
#   'W_user_id': '5726009017',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 791,
#   'W_weibo_id': '1736667765_HCyMoFoT1',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '北京apm',
#   'W_weibo_url': 'https://weibo.com/1736667765/HCyMoFoT1',
#   'W_created_at': '2019-07-08T22:00:00',
#   'W_like_num': 139,
#   'W_repost_num': 115,
#   'W_comment_num': 22,
#   'W_content': '#美妆课堂#【@Innisfree悦诗风吟】 今天我们来讲讲护肤品的#垃圾分类#吧～门店还能帮你分担一部分，帮你回收，让你不再头疼。 颜值打卡：北京apm 1层',
#   'W_user_id': '1736667765',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 8520,
#   'W_weibo_id': '1937618377_ovmXQ8',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/ovmXQ8',
#   'W_created_at': '2011-07-24T17:49:53',
#   'W_like_num': 0,
#   'W_repost_num': 4,
#   'W_comment_num': 1,
#   'W_content': '入住北京饭店，SIGIR注册很快捷，一切搞定。坐车从机场到北京饭店，从无雨，小雨，渐渐变大，不过算是洗尘接风，没有大碍。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 5947,
#   'W_weibo_id': '2152024140_F9Td9p0CR',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/F9Td9p0CR',
#   'W_created_at': '2017-06-28T11:13:30',
#   'W_like_num': 9,
#   'W_repost_num': 2,
#   'W_comment_num': 1,
#   'W_content': '北大计算机强势招生宣传。『集成天下 网络八方 新设图灵班｜北京大学信息科学技术学院』集成天下 网络八方 新设图灵班｜北京大学信息科学技术学院',
#   'W_user_id': '2152024140',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone 6s Plus',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:21:00'},
#  {'W_ID': 9197,
#   'W_weibo_id': '1937618377_xCkWSkgBC',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/xCkWSkgBC',
#   'W_created_at': '2011-12-16T23:24:26',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '北京电视台正在播报微博管理规定。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPad客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T13:14:00'},
#  {'W_ID': 8522,
#   'W_weibo_id': '1937618377_oumZSs',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/oumZSs',
#   'W_created_at': '2011-07-24T15:24:36',
#   'W_like_num': 0,
#   'W_repost_num': 1,
#   'W_comment_num': 1,
#   'W_content': '刚才机长广播，因未获北京方面批准，还不能确定起飞时间。同时，恳请如果乘客与北京空中管制有关系，请帮忙联系。有意思…',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '短信',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 10930,
#   'W_weibo_id': '1937618377_AljXlhy9C',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/AljXlhy9C',
#   'W_created_at': '2013-12-01T21:50:33',
#   'W_like_num': 0,
#   'W_repost_num': 16,
#   'W_comment_num': 1,
#   'W_content': '//@马少平THU: //@石鼓钟山://@李武军sjtu: //@密州小易:北京的ICML 2014，深圳的ICDM 2014，上海的CIKM 2014，杭州的VLDB 2014，北京的ACL 2015，多种回国机会要抓住呀[哈哈]',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '搜狗高速浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/Ahv4a8PyQ?rl=0#cmtfrm',
#   'W_origin_weibo_content': 'ICDM 2014在深圳开，http://t.cn/zlkOcF5， 方便喽',
#   'W_crawl_time': '2019-07-16T15:43:00'},
#  {'W_ID': 9650,
#   'W_weibo_id': '1937618377_yepM3aZHB',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/yepM3aZHB',
#   'W_created_at': '2012-04-13T14:18:30',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 1,
#   'W_content': '#婺源会议#语言信息熵：北京：11.45；台北：11.69；香港：11.9。基于两岸三地共时语料库研究。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T13:47:00'},
#  {'W_ID': 2062,
#   'W_weibo_id': '2952435102_HDKb74Zah',
#   'W_search_query': '#赵丽颖产后现身#',
#   'W_nick_name': '北京热门搜罗',
#   'W_weibo_url': 'https://weibo.com/2952435102/HDKb74Zah',
#   'W_created_at': '2019-07-16T16:51:00',
#   'W_like_num': 184,
#   'W_repost_num': 638,
#   'W_comment_num': 326,
#   'W_content': '#赵丽颖产后现身# 当妈后的颖宝终于露面了！16日，@赵丽颖 现身北京机场，身穿蓝紫色长裙和白色帆布鞋，虽然戴着帽子口罩包裹严实， 但看得出产后身材恢复得很好，腰肢依旧纤细似少女~[色] （via.新浪娱乐）北京 #北京身边事# [组图共9张]',
#   'W_user_id': '2952435102',
#   'W_image_url': 'http://wx1.sinaimg.cn/wap180/affa959egy1g51s2wkwxej20c80icwfa.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T19:47:00'},
#  {'W_ID': 9916,
#   'W_weibo_id': '1937618377_ymURjDHNp',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/ymURjDHNp',
#   'W_created_at': '2012-06-08T12:09:04',
#   'W_like_num': 0,
#   'W_repost_num': 4,
#   'W_comment_num': 0,
#   'W_content': '//@任勇_东京大学:Mark//@董力at北航:论文地址：http://t.cn/zOFWMEE',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/ymUFkes7M?rl=0#cmtfrm',
#   'W_origin_weibo_content': 'MSR研究人员结合心理学模型和crowdsourcing建立情感词典，从Twitter检测出203种细分情绪。他们发现负面情绪出现更加频繁并且更加多样化；Twitter中强社交关系用户之间情感交互反而少，说明媒介性质影响情绪强度；正向情绪内容更容易被“活跃”用户转发并在Twitter上传播。http://t.cn/zOFOZoi',
#   'W_crawl_time': '2019-07-16T14:07:00'},
#  {'W_ID': 16722,
#   'W_weibo_id': '1677746711_HgiJvE7H5',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/HgiJvE7H5',
#   'W_created_at': '2019-02-12T12:42:00',
#   'W_like_num': 23,
#   'W_repost_num': 1,
#   'W_comment_num': 0,
#   'W_content': '北京终于下雪了！但错过了2018，也错过了戊戌年。',
#   'W_user_id': '1677746711',
#   'W_image_url': 'http://wx2.sinaimg.cn/wap180/64006217ly1g03jdm6oz9j21860u0b2e.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:35:00'},
#  {'W_ID': 16526,
#   'W_weibo_id': '5546539755_FyB0FrZsv',
#   'W_search_query': 'None',
#   'W_nick_name': '黄广斌-ELM',
#   'W_weibo_url': 'https://weibo.com/5546539755/FyB0FrZsv',
#   'W_created_at': '2017-12-07T22:50:54',
#   'W_like_num': 11,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '应邀周六到北大参加北大博士生们的人工智能对话，周日也会在北大周一在北京化工大学做ELM学术报告，欢迎大家参加。',
#   'W_user_id': '5546539755',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:30:00'},
#  {'W_ID': 2785,
#   'W_weibo_id': '5261263846_HDLLS0GVv',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '微课堂',
#   'W_weibo_url': 'https://weibo.com/5261263846/HDLLS0GVv',
#   'W_created_at': '2019-07-16T20:54:00',
#   'W_like_num': 12,
#   'W_repost_num': 5,
#   'W_comment_num': 2,
#   'W_content': '【#清华公布在京本科提档线# 理科680分、文科668分】北京教育考试院公布2019年北京市高招本科普通提档线。各大在京重点高校分数线出炉。这也是一本二本合并之后，各大高校在京本科普通批提档线首次出炉。今年，清华在京本科一批次录取分数线理科680分，文科668分，全部位居在京招生全国高校之首。#微课堂#',
#   'W_user_id': '5261263846',
#   'W_image_url': 'http://wx3.sinaimg.cn/wap180/005K3J4ily1g51z43sbu0j30tx37u1ky.jpg',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:13:00'},
#  {'W_ID': 460,
#   'W_weibo_id': '1429074632_HDLPQFOMn',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '老刘in西安',
#   'W_weibo_url': 'https://weibo.com/1429074632/HDLPQFOMn',
#   'W_created_at': '2019-07-16T21:04:00',
#   'W_like_num': 17,
#   'W_repost_num': 4,
#   'W_comment_num': 4,
#   'W_content': '#清华公布在京本科提档线# 说好的北京学子400分上北大清华呢？[允悲][允悲][允悲]清华北大哪里学生都不好考，别想的那么简单。当我听了一个段子后再也没有觉得北京孩子幸福:   楼主问：孩子4岁，英语词汇量只有1500左右，是不是不太够？答：在美国肯定是够了，在海淀肯定是不够。',
#   'W_user_id': '1429074632',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '你不能错过的微博',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:13:00'},
#  {'W_ID': 6662,
#   'W_weibo_id': '1970879995_D6LRIn2c9',
#   'W_search_query': ' ',
#   'W_nick_name': '孙茂松',
#   'W_weibo_url': 'https://weibo.com/1970879995/D6LRIn2c9',
#   'W_created_at': '2015-12-04T01:31:57',
#   'W_like_num': 17,
#   'W_repost_num': 3,
#   'W_comment_num': 3,
#   'W_content': '今晚10时许从呼和浩特飞北京。空姐体贴地对我说：先生，今晚北京大风，降落时可能会有些颠簸，特提请您注意一下。我问道：听说昨天的航班降落时颠簸的很厉害？有点吓人？空姐答曰：是呀！可没有这么大的风，怎么能把北京的雾霾刮跑呢？',
#   'W_user_id': '1970879995',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T14:14:00'},
#  {'W_ID': 9399,
#   'W_weibo_id': '1937618377_y2x9raJbU',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/y2x9raJbU',
#   'W_created_at': '2012-01-26T11:01:42',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '//@王海勋haixun: 政治租界，这个词不错。 //@孙健敏:二三十年代上海有租界，所以上海是中国的文化中心。现在那里一切被控盘，反而北京，到处有和北京市同级别，甚至来头更大的政治租界，所以北京理所当然是文化中心。文化这东西跟自由成正比。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/y2s3cFqh2?rl=0#cmtfrm',
#   'W_origin_weibo_content': '马路很宽令城市无趣。复兴路，华山路，兴国路，长乐路，新乐路，马当路等等，都只两道，固上海多单行道，这常令外地司机抓狂，可你从马路这边望见对面心仪的小铺，两三步穿将过去的欢欣是难以形容的。望着京城浩荡的八车道，便压抑了逛街的心。上海女子的讲究是这一条条小马路两边小小的店家熏出来的。',
#   'W_crawl_time': '2019-07-16T13:26:00'},
#  {'W_ID': 1468,
#   'W_weibo_id': '2189978113_HCG2WqBzX',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '文明北京',
#   'W_weibo_url': 'https://weibo.com/2189978113/HCG2WqBzX',
#   'W_created_at': '2019-07-09T16:30:00',
#   'W_like_num': 1,
#   'W_repost_num': 5,
#   'W_comment_num': 4,
#   'W_content': '#垃圾分类#【历时十年 朝阳区建立垃圾分类完整闭环模式】2009年以来，北京朝阳区就遵循生活垃圾 “减量化、资源化、无害化”原则，在辖区内开展垃圾分类工作。截至目前，朝阳区已在19个街乡开展了垃圾分类示范片区创建工作，涉及居民小区1055个，约201万人，形成了从前端投放、收集、转运到末端处理消纳全过程的垃圾分类模式。到2019年年底，朝阳区计划实现垃圾分类全覆盖。来源：北京日报[组图共4张]',
#   'W_user_id': '2189978113',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 5814,
#   'W_weibo_id': '2152024140_GC1hFxtMK',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/GC1hFxtMK',
#   'W_created_at': '2018-10-02T09:59:25',
#   'W_like_num': 14,
#   'W_repost_num': 5,
#   'W_comment_num': 2,
#   'W_content': '国庆长假跟北大同学们一起学习『数据结构与算法_北京大学_中国大学MOOC(慕课)』http://t.cn/RnhEwbs',
#   'W_user_id': '2152024140',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:18:00'},
#  {'W_ID': 8327,
#   'W_weibo_id': '1937618377_hjgBeO',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/hjgBeO',
#   'W_created_at': '2011-05-16T13:24:27',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 1,
#   'W_content': '北京的领导太多了，一个接一个先飞，你要有耐心哟。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/hjeNsz?rl=0#cmtfrm',
#   'W_origin_weibo_content': '北京机场候机，飞机晚点一个多小时。不知道是不是又是让领导先飞啊。',
#   'W_crawl_time': '2019-07-16T11:42:00'},
#  {'W_ID': 5813,
#   'W_weibo_id': '2152024140_GCpLXiM7w',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/GCpLXiM7w',
#   'W_created_at': '2018-10-05T00:19:56',
#   'W_like_num': 5,
#   'W_repost_num': 0,
#   'W_comment_num': 3,
#   'W_content': '北京大学招生办宣传北大计算机专业的暑期课程被北大刷脸迎新的AI圈粉？北大信科计算机科学前沿交叉系列暑期课程了解一下',
#   'W_user_id': '2152024140',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:18:00'},
#  {'W_ID': 11132,
#   'W_weibo_id': '1937618377_AEfgedB7O',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/AEfgedB7O',
#   'W_created_at': '2014-04-05T08:49:08',
#   'W_like_num': 1,
#   'W_repost_num': 2,
#   'W_comment_num': 3,
#   'W_content': '想起了一个段子：在北京郊区买房，验房时，手机里面接到一条短信：河北人民欢迎你。[偷笑]',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '搜狗高速浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/AEb9V4nB8?rl=0#cmtfrm',
#   'W_origin_weibo_content': '经中国移动海南公司核实，“欢迎来中国”短信是菲律宾手机用户漫游到中国移动网络发送。经核查，3月29日中国移动南沙基站网络确有数个菲律宾电信运营商GLOBETELECOM用户登录，并有数十条通信记录。',
#   'W_crawl_time': '2019-07-16T15:57:00'},
#  {'W_ID': 2867,
#   'W_weibo_id': '5391596582_HDLX2CkM9',
#   'W_search_query': '#80名儿童贴三伏贴后被灼伤#',
#   'W_nick_name': '掌上镇江',
#   'W_weibo_url': 'https://weibo.com/5391596582/HDLX2CkM9',
#   'W_created_at': '2019-07-16T21:22:00',
#   'W_like_num': 44,
#   'W_repost_num': 35,
#   'W_comment_num': 15,
#   'W_content': '#80名儿童贴三伏贴后被灼伤#首都医科大学附属北京儿童医院中医科主治医师，告诉你孩子适合贴“三伏贴”吗？到底能不能贴呀？↓↓北京市教委的微博视频',
#   'W_user_id': '5391596582',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:14:00'},
#  {'W_ID': 5308,
#   'W_weibo_id': '1744851064_Aeh80kOsM',
#   'W_search_query': ' ',
#   'W_nick_name': '1744851064',
#   'W_weibo_url': 'https://weibo.com/1744851064/Aeh80kOsM',
#   'W_created_at': '2013-10-16T13:46:28',
#   'W_like_num': 5,
#   'W_repost_num': 11,
#   'W_comment_num': 2,
#   'W_content': '缓解北京人口最好的方法不是限制进入，而是减少北京的资源投入，加强落后地区的建设，减低城乡的差距，中国问题不是人口太多，而是分布不合理。',
#   'W_user_id': '1744851064',
#   'W_image_url': 'http://ww1.sinaimg.cn/wap180/6a5ce645jw1e9mtwerqb4j20c80bhgnc.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/AefXLfi4h?rl=0#cmtfrm',
#   'W_origin_weibo_content': '【[话筒]北京控制大学生进京户口指标 每年一万个以内】近几年，北京市大学生进京户口指标数量都控制在1万个以内，预计明年会保持稳定，主要是16个区县所属人才中心和市属大型国企等单位有指标。目前，进京指标管理严格，落户后违约可注销户口。同学，你有信心成为“万分之一”吗？http://t.cn/zRcUQI3',
#   'W_crawl_time': '2019-07-18T12:44:00'},
#  {'W_ID': 16877,
#   'W_weibo_id': '1677746711_GaOw4rh11',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/GaOw4rh11',
#   'W_created_at': '2018-04-06T11:51:00',
#   'W_like_num': 25,
#   'W_repost_num': 1,
#   'W_comment_num': 2,
#   'W_content': '北京难得的景象：树绿了，花红了，人们穿上棉衣了。[嘻嘻]',
#   'W_user_id': '1677746711',
#   'W_image_url': 'http://wx4.sinaimg.cn/wap180/64006217ly1fq2slde7umj21kw11jnpf.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:37:00'},
#  {'W_ID': 704,
#   'W_weibo_id': '1676679984_HDN4oA5IJ',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '张雪峰老师',
#   'W_weibo_url': 'https://weibo.com/1676679984/HDN4oA5IJ',
#   'W_created_at': '2019-07-17T00:13:00',
#   'W_like_num': 515,
#   'W_repost_num': 4,
#   'W_comment_num': 73,
#   'W_content': '#清华公布在京本科提档线#这是清华最后一年在北京有提档线这个概念了[挖鼻][挖鼻][挖鼻][挖鼻]',
#   'W_user_id': '1676679984',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'HUAWEI Mate 20 Pro',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T09:07:00'},
#  {'W_ID': 646,
#   'W_weibo_id': '1651428902_HDLEPxjZI',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '21世纪经济报道',
#   'W_weibo_url': 'https://weibo.com/1651428902/HDLEPxjZI',
#   'W_created_at': '2019-07-16T20:37:00',
#   'W_like_num': 17,
#   'W_repost_num': 4,
#   'W_comment_num': 0,
#   'W_content': '【#清华公布在京本科提档线#：理科681分 文科673分】7月16日，清华大学等多数高校公布了在京本科提档线，其中清华大学理科681分，文科673分。今年北京各校的提档线理科普遍与去年持平，而文科提档线却比去年有较大幅度下降。（北京青年报）',
#   'W_user_id': '1651428902',
#   'W_image_url': 'http://wx1.sinaimg.cn/wap180/626ece26gy1g51yljr95zj20xc0m8n7n.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:13:00'},
#  {'W_ID': 16853,
#   'W_weibo_id': '1677746711_FAey7hhQN',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/FAey7hhQN',
#   'W_created_at': '2017-12-18T17:20:44',
#   'W_like_num': 29,
#   'W_repost_num': 0,
#   'W_comment_num': 1,
#   'W_content': '#北京大学本科教学计划# 感觉这是做了件重要的事情。[ok]',
#   'W_user_id': '1677746711',
#   'W_image_url': 'http://wx3.sinaimg.cn/wap180/64006217ly1fml1ja5djyj21kw1nge82.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:36:00'},
#  {'W_ID': 16970,
#   'W_weibo_id': '1405078654_GhufB8yLc',
#   'W_search_query': 'None',
#   'W_nick_name': '孙晓HFUT',
#   'W_weibo_url': 'https://weibo.com/1405078654/GhufB8yLc',
#   'W_created_at': '2018-05-20T09:07:34',
#   'W_like_num': 5,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': 'ACII Asia 2018 @自动化所 北京 情感计算与智能交互 [组图共2张]',
#   'W_user_id': '1405078654',
#   'W_image_url': 'http://wx1.sinaimg.cn/wap180/53bfcc7ely1frhj66qamnj21bf0qok48.jpg',
#   'W_video_url': 'None',
#   'W_tool': '',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:41:00'},
#  {'W_ID': 17324,
#   'W_weibo_id': '2133193332_C3Vvdrlub',
#   'W_search_query': 'None',
#   'W_nick_name': '赵鑫RUC',
#   'W_weibo_url': 'https://weibo.com/2133193332/C3Vvdrlub',
#   'W_created_at': '2015-02-12T09:48:47',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 5,
#   'W_content': '感觉快要回不去北京了。。。3月1-3号的火车票都没有了。',
#   'W_user_id': '2133193332',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博手机版',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T11:03:00'},
#  {'W_ID': 597,
#   'W_weibo_id': '1644948230_HDKTPq55N',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '北京头条',
#   'W_weibo_url': 'https://weibo.com/1644948230/HDKTPq55N',
#   'W_created_at': '2019-07-16T18:41:00',
#   'W_like_num': 1743,
#   'W_repost_num': 461,
#   'W_comment_num': 4454,
#   'W_content': '【#清华公布在京本科提档线#：理科681分 文科673分】7月16日，清华大学等多数高校公布了在京本科提档线，其中清华大学理科681分，文科673分。北京青年报记者比较后发现，今年各校的提档线理科普遍与去年持平，而文科提档线却比去年有较大幅度下降。 先看理工类，与去年相比，波动幅度不超过4分。清华大学今年681分，去年685分；北京航空航天大学今年661分，去年664分；中央财经大学今年651分，去年650分；中国农业大学今年633分，去年634分；中国政法大学今年和去年一样，都是643分；北京林业大学今年615分，去年616分；北京工业大学今年602分，去年601分。 文科类则普遍比去年下降了10-20分之间。清华大学今年673分，去年687分；北京航空航天大学今年633分，去年649分；中央财经大学今年629分，去年648分；中国农业大学今年622分，去年640分；中国政法大学今年628分，去年645分；北京林业大学今年614分，去年630分；北京工业大学今年597分，去年613分。文／北京青年报记者 雷嘉 http://t.cn/AiW168Kl',
#   'W_user_id': '1644948230',
#   'W_image_url': 'http://wx2.sinaimg.cn/wap180/620beb06ly1g51vag1kd1j20go08z74t.jpg',
#   'W_video_url': 'None',
#   'W_tool': '搜狗高速浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T09:07:00'},
#  {'W_ID': 4117,
#   'W_weibo_id': '2993883977_AljYFswBP',
#   'W_search_query': ' ',
#   'W_nick_name': '2993883977',
#   'W_weibo_url': 'https://weibo.com/2993883977/AljYFswBP',
#   'W_created_at': '2013-12-01T21:53:50',
#   'W_like_num': 0,
#   'W_repost_num': 2,
#   'W_comment_num': 0,
#   'W_content': '//@于亻士王其://@KJ音乐人生_CASIA: @guoweiyu168 @吴书_自动化所 //@王帅强SDUFE:赞！在国内开的顶会越来越多了//@密州小易: 北京的ICML 2014，深圳的ICDM 2014，上海的CIKM 2014，杭州的VLDB 2014，北京的ACL 2015',
#   'W_user_id': '2993883977',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'Android客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/Ahv4a8PyQ?rl=0#cmtfrm',
#   'W_origin_weibo_content': 'ICDM 2014在深圳开，http://t.cn/zlkOcF5， 方便喽',
#   'W_crawl_time': '2019-07-17T16:44:00'},
#  {'W_ID': 5835,
#   'W_weibo_id': '2152024140_H7vpL1MTN',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/H7vpL1MTN',
#   'W_created_at': '2018-12-16T16:26:36',
#   'W_like_num': 10,
#   'W_repost_num': 2,
#   'W_comment_num': 0,
#   'W_content': '北京大学计算机学科拔尖人才计划十周年总结交流会，2009-2014级校友，以及2016-2017图灵班部分师生合影 预告 | 北京大学计算机学科拔尖人才计划十周年总结交流会',
#   'W_user_id': '2152024140',
#   'W_image_url': 'http://wx1.sinaimg.cn/wap180/8045484cly1fy8nzqmr8tj21ao0qo19s.jpg',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:18:00'},
#  {'W_ID': 8521,
#   'W_weibo_id': '1937618377_ov4vio',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/ov4vio',
#   'W_created_at': '2011-07-24T16:45:43',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '终于落地了，还算顺利。北京的天灰蒙蒙的，真不是晴朗的天。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '短信',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 8968,
#   'W_weibo_id': '1937618377_xqQtlAB3H',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/xqQtlAB3H',
#   'W_created_at': '2011-10-02T09:35:57',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '在北京摩天大厦里练习过N次，成功率百分百，真有动力呀。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/xqQsvht3l?rl=0#cmtfrm',
#   'W_origin_weibo_content': '真的猛士，就是把新娘子从六楼抱下来再走100多米，面不改色心不跳！倪茂树，你真爷们！',
#   'W_crawl_time': '2019-07-16T12:42:00'},
#  {'W_ID': 2592,
#   'W_weibo_id': '5030938069_HBM1dhmh5',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '大众健康世界',
#   'W_weibo_url': 'https://weibo.com/5030938069/HBM1dhmh5',
#   'W_created_at': '2019-07-03T17:51:00',
#   'W_like_num': 135,
#   'W_repost_num': 77,
#   'W_comment_num': 22,
#   'W_content': '【你是个什么垃圾？】#垃圾分类# 北京也要开始啦！罚款不会低于上海。北京的垃圾分类标准与上海并不完全一致，分为厨余垃圾、有害垃圾、其它垃圾及可回收物。那么垃圾分类，广州、深圳还会远吗？[允悲] 那区分垃圾的口诀，你都知道哪些呢？ 来[来]一招记住垃圾分类： 猪能吃的是湿垃圾 猪不能吃的的是干垃圾 猪吃了会shi的是有害垃圾 可以卖出去换猪的是可回收垃圾 [猪头] 保护环境，人人有责，垃圾分类，让中国变得更美！[围观][组图共3张]',
#   'W_user_id': '5030938069',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 322,
#   'W_weibo_id': '1214199295_HB6hklpk1',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '黄胜友',
#   'W_weibo_url': 'https://weibo.com/1214199295/HB6hklpk1',
#   'W_created_at': '2019-06-29T07:36:00',
#   'W_like_num': 5,
#   'W_repost_num': 5,
#   'W_comment_num': 1,
#   'W_content': '北京垃圾分类责任也即将立法。 上海的朋友们快来传授一下经验。 羊蝎子、小龙虾、大闸蟹、皮皮虾、骨头棒子都是什么垃圾啊[晕]？ 前男友扔那个桶里呢？[笑哈哈]#垃圾分类##上海垃圾分类# [组图共2张]',
#   'W_user_id': '1214199295',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 702,
#   'W_weibo_id': '1672238845_HBBda40Ul',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '南京十八频道',
#   'W_weibo_url': 'https://weibo.com/1672238845/HBBda40Ul',
#   'W_created_at': '2019-07-02T14:21:00',
#   'W_like_num': 49,
#   'W_repost_num': 26,
#   'W_comment_num': 28,
#   'W_content': '#南京身边事#【官方回应：南京什么时候会实行垃圾强制分类？】网传12个街道将实行#垃圾分类# ，是不是真的？南京城管今天全部给了回应，答案戳视频☞  南京十八频道的微博视频',
#   'W_user_id': '1672238845',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '360安全浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 833,
#   'W_weibo_id': '1749990115_HDKRG9mJj',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '北京青年报',
#   'W_weibo_url': 'https://weibo.com/1749990115/HDKRG9mJj',
#   'W_created_at': '2019-07-16T18:36:00',
#   'W_like_num': 2609,
#   'W_repost_num': 584,
#   'W_comment_num': 8122,
#   'W_content': '【#清华公布在京本科提档线#：理科681分 文科673分】7月16日，清华大学等多所高校公布了在京本科提档线，其中清华大学理科681分，文科673分。北京青年报记者比较后发现，今年各校的提档线理科普遍与去年持平，而文科提档线却比去年有较大幅度下降。 先看理工类，与去年相比，波动幅度不超过4分。清华大学今年681分，去年685分；北京航空航天大学今年661分，去年664分；中央财经大学今年651分，去年650分；中国农业大学今年633分，去年634分；中国政法大学今年和去年一样，都是643分；北京林业大学今年615分，去年616分；北京工业大学今年602分，去年601分。 文科类则普遍比去年下降了10-20分之间。清华大学今年673分，去年687分；北京航空航天大学今年633分，去年649分；中央财经大学今年629分，去年648分；中国农业大学今年622分，去年640分； 中国政法大学今年628分，去年645分；北京林业大学今年614分，去年630分；北京工业大学今年597分，去年613分。（北青报记者 雷嘉）http://t.cn/AiW168Kl',
#   'W_user_id': '1749990115',
#   'W_image_url': 'http://wx4.sinaimg.cn/wap180/684ebae3ly1g51usf5vjnj20go08zmxp.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T09:07:00'},
#  {'W_ID': 2558,
#   'W_weibo_id': '3951710017_HDQpukJ1W',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '曲靖检察',
#   'W_weibo_url': 'https://weibo.com/3951710017/HDQpukJ1W',
#   'W_created_at': '2019-07-17T08:43:00',
#   'W_like_num': 14,
#   'W_repost_num': 7,
#   'W_comment_num': 12,
#   'W_content': '#曲检播报# 【#清华公布在京本科提档线#：理科681分 文科673分】7月16日，清华大学等多所高校公布了在京本科提档线，其中清华大学理科681分，文科673分。北京青年报记者比较后发现，今年各校的提档线理科普遍与去年持平，而文科提档线却比去年有较大幅度下降。 先看理工类，与去年相比，波动幅度不超过4分。清华大学今年681分，去年685分；北京航空航天大学今年661分，去年664分；中央财经大学今年651分，去年650分；中国农业大学今年633分，去年634分；中国政法大学今年和去年一样，都是643分；北京林业大学今年615分，去年616分；北京工业大学今年602分，去年601分。 文科类则普遍比去年下降了10-20分之间。清华大学今年673分，去年687分；北京航空航天大学今年633分，去年649分；中央财经大学今年629分，去年648分；中国农业大学今年622分，去年640分； 中国政法大学今年628分，去年645分；北京林业大学今年614分，去年630分；北京工业大学今年597分，去年613分。（北青报记者 雷嘉）',
#   'W_user_id': '3951710017',
#   'W_image_url': 'http://wx2.sinaimg.cn/wap180/eb8a4f41gy1g52jle0y6vj20rn0q91cl.jpg',
#   'W_video_url': 'None',
#   'W_tool': '360安全浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:13:00'},
#  {'W_ID': 1718,
#   'W_weibo_id': '2564717617_Glr3HaGxH',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '南京城管',
#   'W_weibo_url': 'https://weibo.com/2564717617/Glr3HaGxH',
#   'W_created_at': '2018-06-15T08:21:14',
#   'W_like_num': 4,
#   'W_repost_num': 23,
#   'W_comment_num': 9,
#   'W_content': '#垃圾分类# 文明南京始于心，垃圾分类践于行 南京城管的秒拍视频',
#   'W_user_id': '2564717617',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '秒拍网页版',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 1720,
#   'W_weibo_id': '2564717617_GnscG4RSc',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '南京城管',
#   'W_weibo_url': 'https://weibo.com/2564717617/GnscG4RSc',
#   'W_created_at': '2018-06-28T14:56:43',
#   'W_like_num': 2,
#   'W_repost_num': 15,
#   'W_comment_num': 6,
#   'W_content': '#垃圾分类# 文明南京始于心，垃圾分类践于行 。 南京城管的秒拍视频',
#   'W_user_id': '2564717617',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '秒拍网页版',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 712,
#   'W_weibo_id': '1682917945_HDHOpeq3M',
#   'W_search_query': '#赵丽颖产后现身#',
#   'W_nick_name': '娱乐先锋队',
#   'W_weibo_url': 'https://weibo.com/1682917945/HDHOpeq3M',
#   'W_created_at': '2019-07-16T10:50:00',
#   'W_like_num': 67,
#   'W_repost_num': 436,
#   'W_comment_num': 5,
#   'W_content': '#赵丽颖产后现身北京机场# ，颖宝的私人行程很低调，包裹得这么严实也能认出来，新鲜的颖宝身材苗条状态很好！16日，赵丽颖身穿蓝紫色长裙和白色帆布鞋现身北京机场，戴着帽子口罩的她包裹严实， 身材苗条腰肢纤细，状态十分不错。#赵丽颖产后现身# 北京 显示地图[组图共9张]',
#   'W_user_id': '1682917945',
#   'W_image_url': 'http://wx2.sinaimg.cn/wap180/644f4a39gy1g51hkwss0ig20az0eqb2g.gif',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': '娱乐先锋队',
#   'W_location_map_info': '116.405289,39.904987',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T20:23:00'},
#  {'W_ID': 3031,
#   'W_weibo_id': '5632570931_HCmitcXCH',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '中国气象数据网',
#   'W_weibo_url': 'https://weibo.com/5632570931/HCmitcXCH',
#   'W_created_at': '2019-07-07T14:13:00',
#   'W_like_num': 14,
#   'W_repost_num': 7,
#   'W_comment_num': 4,
#   'W_content': '《蜡笔小新》关于#垃圾分类#的一集，丢了好几次都丢不掉，你到底是什么垃圾？！[哈哈][允悲] #八成重点城市用垃圾四分法##上海垃圾分类6天开190张罚单#人人视频的酷燃视频 （人人视频）  北京 · 后沙峪 显示地图',
#   'W_user_id': '5632570931',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone X',
#   'W_location': '中国气象数据网',
#   'W_location_map_info': '116.482162,40.102818',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 2063,
#   'W_weibo_id': '2952435102_HDMEe4Dpl',
#   'W_search_query': '#清华公布在京本科提档线#',
#   'W_nick_name': '北京热门搜罗',
#   'W_weibo_url': 'https://weibo.com/2952435102/HDMEe4Dpl',
#   'W_created_at': '2019-07-16T23:08:00',
#   'W_like_num': 171,
#   'W_repost_num': 654,
#   'W_comment_num': 326,
#   'W_content': '#清华公布在京本科提档线#【[话筒]清华公布在京本科提档线：理科681分 文科673分】16日，清华大学等多高校公布了在京本科提档线，其中清华大学理科681分，文科673分。记者比较后发现，今年各校的提档线理科普遍与去年持平，而文科提档线却比去年有较大幅度下降。（北京青年报）http://t.cn/ELT0hke #北京身边事#',
#   'W_user_id': '2952435102',
#   'W_image_url': 'http://wx3.sinaimg.cn/wap180/affa959egy1g522zfiwn3j20c806ljrm.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:13:00'},
#  {'W_ID': 5790,
#   'W_weibo_id': '2152024140_Gam24ArXZ',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/Gam24ArXZ',
#   'W_created_at': '2018-04-03T11:20:10',
#   'W_like_num': 5,
#   'W_repost_num': 12,
#   'W_comment_num': 5,
#   'W_content': '北大计算机学科前沿国际暑期http://t.cn/S6cYmW 。北大校内本科生4.16 开始选课。课程对东亚研究型大学AEARU （香港科技大学、北京大学、、复旦大学、南京大学和中国科学技术大学）学生免费开放，请发邮件咨询summerschool@pku.edu.cn。其他高校自费。『信科暑期课程』http://t.cn/RmvQLfb',
#   'W_user_id': '2152024140',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:17:00'},
#  {'W_ID': 771,
#   'W_weibo_id': '1730243272_HwIlKnI3o',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '第一时间',
#   'W_weibo_url': 'https://weibo.com/1730243272/HwIlKnI3o',
# ...
#   'W_content': '车上播放张学良传记，张学良说道：孙中山在北京的医院里对张学良说，中国的未来在你们年青人手里，你是东北人，东北介乎红白两帝之间，责任重大。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T14:06:00'},
#  {'W_ID': 2965,
#   'W_weibo_id': '5575615685_HDI55aadC',
#   'W_search_query': '#119吗我是110#',
#   'W_nick_name': '房山警方在线',
#   'W_weibo_url': 'https://weibo.com/5575615685/HDI55aadC',
#   'W_created_at': '2019-07-16T11:31:00',
#   'W_like_num': 45,
#   'W_repost_num': 12,
#   'W_comment_num': 20,
#   'W_content': '#119吗我是110#  夏季炎热，大家心情都很暴躁，房山警方在此温馨提示您： 寻衅滋事、打架斗殴 您将享受派出所体验游一次 请不要试图逃跑 我们的手铐 119见了都说好@北京消防 @北京房山消防',
#   'W_user_id': '5575615685',
#   'W_image_url': 'http://wx1.sinaimg.cn/wap180/0065kIlfly1g51isvteosj30fa0a6t99.jpg',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T18:24:00'},
#  {'W_ID': 16699,
#   'W_weibo_id': '1677746711_H1SbMhpLC',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/H1SbMhpLC',
#   'W_created_at': '2018-11-09T15:23:32',
#   'W_like_num': 7,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '最近两周乘高铁出门，一次从北京西站，一次从北京南站。发现从地铁转接火车的过程都痛快了不少。仔细观察下，也就是结合部的场地格局做了些调整。最初为什么没能设计成这样呢？[挤眼]',
#   'W_user_id': '1677746711',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:35:00'},
#  {'W_ID': 8516,
#   'W_weibo_id': '1937618377_othBjs',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/othBjs',
#   'W_created_at': '2011-07-24T12:57:43',
#   'W_like_num': 0,
#   'W_repost_num': 1,
#   'W_comment_num': 6,
#   'W_content': '大连机场有雾，不是很严重，希望北京机场是＂解放区的天＂，晴朗的天。如愿否？',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '短信',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 8558,
#   'W_weibo_id': '1937618377_pi2IZc',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/pi2IZc',
#   'W_created_at': '2011-07-30T17:03:40',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 7,
#   'W_content': '东边日出西边雨，大连无晴北京晴。望着首都机场上空的阳光，能否捎到大连？',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 8106,
#   'W_weibo_id': '1937618377_eDqr48',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/eDqr48',
#   'W_created_at': '2011-04-13T14:55:41',
#   'W_like_num': 0,
#   'W_repost_num': 1,
#   'W_comment_num': 4,
#   'W_content': '望着京城的满城翠绿，北方还只是草色遥看近却无，再看看南方已是暮春时节。信息的传播也是呈梯度状，虽然借助网络压缩了时空尺度，但形式未变，中心结点非常重要。条条大道通罗马，根根网线连北京。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '短信',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T11:20:00'},
#  {'W_ID': 17267,
#   'W_weibo_id': '5866810652_ErvXrf8DP',
#   'W_search_query': 'None',
#   'W_nick_name': 'AndrewNg吴恩达',
#   'W_weibo_url': 'https://weibo.com/5866810652/ErvXrf8DP',
#   'W_created_at': '2017-01-19T10:22:47',
#   'W_like_num': 210,
#   'W_repost_num': 38,
#   'W_comment_num': 20,
#   'W_content': '在北京地铁上，我们发起了一场通过增强现实（AR）技术激活100年前老照片、复原老北京九大城门的活动，让乘客们“穿越”了时空，用技术温暖人心。希望大家可以有机会到地铁体验这个AR效果！ [组图共3张]',
#   'W_user_id': '5866810652',
#   'W_image_url': 'http://wx3.sinaimg.cn/wap180/006p2xsggy1fbvq5dozllj30vk0l1tbe.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:55:00'},
#  {'W_ID': 5856,
#   'W_weibo_id': '2152024140_HqtzGhABs',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/HqtzGhABs',
#   'W_created_at': '2019-04-20T10:41:00',
#   'W_like_num': 8,
#   'W_repost_num': 0,
#   'W_comment_num': 1,
#   'W_content': '2019年北京大学运动会，教工运动会和学生运动会合并举办http://t.cn/EahS0jl [组图共9张]',
#   'W_user_id': '2152024140',
#   'W_image_url': 'http://wx2.sinaimg.cn/wap180/8045484cly1g28wg87ayhj21hc0u0b0a.jpg',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:18:00'},
#  {'W_ID': 8607,
#   'W_weibo_id': '1937618377_opccB2',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/opccB2',
#   'W_created_at': '2011-07-23T21:51:52',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '明天要出差，去北京开会，正在处理一些事情。才看见你的微博，祝你们玩得愉快。',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/ootMNK?rl=0#cmtfrm',
#   'W_origin_weibo_content': '@-林鸿飞- 林老师，时达明前来报到。我们05级在大连的这几个人正在聚会呢。',
#   'W_crawl_time': '2019-07-16T12:07:00'},
#  {'W_ID': 16876,
#   'W_weibo_id': '1677746711_G5ulJ2hbZ',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/G5ulJ2hbZ',
#   'W_created_at': '2018-03-02T11:19:03',
#   'W_like_num': 22,
#   'W_repost_num': 10,
#   'W_comment_num': 1,
#   'W_content': '新学期，新气象，北京大学十多门慕课本学期将同时在中国大学MOOC平台上开出！',
#   'W_user_id': '1677746711',
#   'W_image_url': 'http://wx1.sinaimg.cn/wap180/64006217ly1foyazj2sjzj20xo0q94n9.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:37:00'},
#  {'W_ID': 887,
#   'W_weibo_id': '1774057271_HBsEpcKAh',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '生命时报',
#   'W_weibo_url': 'https://weibo.com/1774057271/HBsEpcKAh',
#   'W_created_at': '2019-07-01T16:33:00',
#   'W_like_num': 155,
#   'W_repost_num': 227,
#   'W_comment_num': 47,
#   'W_content': '#垃圾分类#【#干垃圾还是湿垃圾#？一张图教你成为垃圾分类专家！[喵喵]】今天《上海市生活垃圾管理条例》正式施行，北京也将实施。可回收物、有害垃圾、湿垃圾、干垃圾，据说上海人民已经要被垃圾分类“逼疯”……垃圾应该怎么扔？戳长图↓包你成为垃圾（分类）专家！',
#   'W_user_id': '1774057271',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 4666,
#   'W_weibo_id': '2993883977_GwTn0r5bE',
#   'W_search_query': ' ',
#   'W_nick_name': '2993883977',
#   'W_weibo_url': 'https://weibo.com/2993883977/GwTn0r5bE',
#   'W_created_at': '2018-08-29T16:39:04',
#   'W_like_num': 5,
#   'W_repost_num': 0,
#   'W_comment_num': 0,
#   'W_content': '2018年8月20-24日，第24届国际模式识别大会（ICPR 2018）在北京国家会议中心成功举行。',
#   'W_user_id': '2993883977',
#   'W_image_url': 'http://wx3.sinaimg.cn/wap180/c0586ca5ly1fuqdf4151lj20bj07it99.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/GwR16cwoV?rl=0#cmtfrm',
#   'W_origin_weibo_content': '本届大会分为6个主题，包括#模式识别#和#机器学习#、#计算机视觉#、语音图像视频和多媒体、#生物识别#技术和人机交互、文档分析和识别以及生物医学成像和#生物信息学#。除了口头报告和海报展示，大会还邀请到6位该领域的顶尖学者做特邀报告，展示该领域最新研究成果。@自动化学院派 模式识别“旗舰会议”首次在中国内地举办',
#   'W_crawl_time': '2019-07-18T11:33:00'},
#  {'W_ID': 9904,
#   'W_weibo_id': '1937618377_yiG7zlowz',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/yiG7zlowz',
#   'W_created_at': '2012-05-11T15:16:41',
#   'W_like_num': 0,
#   'W_repost_num': 3,
#   'W_comment_num': 0,
#   'W_content': '//@鳳凰網事://@薛蛮子: 北京日报改了版了，日下专营笑话，而且还是冷笑话。大家同意吗',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone客户端',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'https://weibo.cn/comment/yiDdgy1gq?rl=0#cmtfrm',
#   'W_origin_weibo_content': '“每当一个国家的政治、经济出现重大危机时，爱国主义破旗就散发出臭味来。”我们不知道列宁这话是不是放之四海而皆准，但读《北京日报》“必须高扬爱国主义旗帜”，不由自主想到了这句话。不知道国家是不是政治经济方面有了问题，但相信北京日报的爱国主义一定不是五四青年的“外争国权，内惩国贼”。',
#   'W_crawl_time': '2019-07-16T14:06:00'},
#  {'W_ID': 16562,
#   'W_weibo_id': '5546539755_GfrZLxnes',
#   'W_search_query': 'None',
#   'W_nick_name': '黄广斌-ELM',
#   'W_weibo_url': 'https://weibo.com/5546539755/GfrZLxnes',
#   'W_created_at': '2018-05-06T23:42:29',
#   'W_like_num': 15,
#   'W_repost_num': 1,
#   'W_comment_num': 7,
#   'W_content': '今天在北京和几个朋友畅谈人工智能。人工智能算法、人才和芯片是中国的短板。',
#   'W_user_id': '5546539755',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:30:00'},
#  {'W_ID': 811,
#   'W_weibo_id': '1740522895_HBqgXgW8r',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '新浪厦门',
#   'W_weibo_url': 'https://weibo.com/1740522895/HBqgXgW8r',
#   'W_created_at': '2019-07-01T10:30:00',
#   'W_like_num': 36,
#   'W_repost_num': 37,
#   'W_comment_num': 5,
#   'W_content': '#轮到你了 垃圾分类宣传片#【纸尿裤、口红往哪儿扔？ 120秒动画看懂怎么#垃圾分类#】北京、上海、广州、厦门等#46城逐步建立生活垃圾处理系统#， 7月1日起，上海将正式实施生活垃圾分类，不少人仍在和“某件垃圾究竟该归为湿垃圾还是干垃圾”的问题缠斗。“铲屎官”犯愁猫砂属于啥垃圾？“小仙女”也为难，化妆品应该丢在哪儿？你需要知道的垃圾分类法都在这儿！@新京报：http://t.cn/Ai05PhPC http://t.cn/EyPFKKk显示地图',
#   'W_user_id': '1740522895',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'None',
#   'W_location': '新浪厦门',
#   'W_location_map_info': '118.048157,24.584497',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 8417,
#   'W_weibo_id': '1937618377_kLn6ok',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/kLn6ok',
#   'W_created_at': '2011-06-24T10:20:44',
#   'W_like_num': 0,
#   'W_repost_num': 0,
#   'W_comment_num': 2,
#   'W_content': '今年夏天，我们相约一起到北京去看海，那里有著名的中南海，北海...，还有积水潭、水帘洞、水上故宫。昨夜星辰之后，更多的传说值得期待...',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T11:55:00'},
#  {'W_ID': 16686,
#   'W_weibo_id': '1677746711_GE8EqvWeL',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/GE8EqvWeL',
#   'W_created_at': '2018-10-16T08:25:19',
#   'W_like_num': 9,
#   'W_repost_num': 1,
#   'W_comment_num': 0,
#   'W_content': '北京大学-UCLA理工联合研究所年会，http://t.cn/E7eWydg，今年“高规格了”——小会，但两个大校长都参加。',
#   'W_user_id': '1677746711',
#   'W_image_url': 'http://wx2.sinaimg.cn/wap180/64006217ly1fw9r5qactaj20wo0j5kjl.jpg',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:34:00'},
#  {'W_ID': 1288,
#   'W_weibo_id': '1979049900_GrpkXbHEG',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '南京高淳城管',
#   'W_weibo_url': 'https://weibo.com/1979049900/GrpkXbHEG',
#   'W_created_at': '2018-07-24T15:00:05',
#   'W_like_num': 3,
#   'W_repost_num': 13,
#   'W_comment_num': 8,
#   'W_content': '#垃圾分类# 农村有机垃圾经过有机（餐厨）垃圾处理机处理，可直接用于田间施肥！@南京城管 @高淳发布 南京高淳城管的秒拍视频',
#   'W_user_id': '1979049900',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博视频',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 2096,
#   'W_weibo_id': '3037284894_HDM3eaEM2',
#   'W_search_query': '#80名儿童贴三伏贴后被灼伤#',
#   'W_nick_name': '经济日报',
#   'W_weibo_url': 'https://weibo.com/3037284894/HDM3eaEM2',
#   'W_created_at': '2019-07-16T21:37:00',
#   'W_like_num': 29,
#   'W_repost_num': 40,
#   'W_comment_num': 26,
#   'W_content': '#80名儿童贴三伏贴后被灼伤#夏季三伏天到来时，很多人都去贴三伏贴，对“冬病夏治”的理念深信不疑。首都医科大学附属北京儿童医院中医科主治医师，告诉你孩子适合贴“三伏贴”吗？到底能不能贴呀？↓↓北京市教委的微博视频',
#   'W_user_id': '3037284894',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '360安全浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-17T14:58:00'},
#  {'W_ID': 16947,
#   'W_weibo_id': '1677746711_HAvpPwBmM',
#   'W_search_query': 'None',
#   'W_nick_name': '北京大学李晓明',
#   'W_weibo_url': 'https://weibo.com/1677746711/HAvpPwBmM',
#   'W_created_at': '2019-06-25T09:45:00',
#   'W_like_num': 19,
#   'W_repost_num': 5,
#   'W_comment_num': 1,
#   'W_content': '#老年编程# 附件视频是北京一位84岁长者最近编的一个程序的运行结果。他用Python编了一个反向传播的神经网络，做数据分类。程序原始输出的是GIF格式的文件，他又用格式工厂把它转换为这个MP4。  北京大学李晓明的秒拍视频',
#   'W_user_id': '1677746711',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '秒拍网页版',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-24T10:38:00'},
#  {'W_ID': 2452,
#   'W_weibo_id': '3933997299_GiU8Gz0EX',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '南京浦口城管',
#   'W_weibo_url': 'https://weibo.com/3933997299/GiU8Gz0EX',
#   'W_created_at': '2018-05-29T16:52:17',
#   'W_like_num': 19,
#   'W_repost_num': 20,
#   'W_comment_num': 21,
#   'W_content': '#垃圾分类# 垃圾分类您了解多少？今日，执法人员加强走访，向辖区内企事业单位发放《推行垃圾分类  共创美好南京》一封信，普及垃圾分类知识，让垃圾分类走进大家的工作和生活。@南京城管 @南京城管执法先锋号 [组图共9张]',
#   'W_user_id': '3933997299',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '360安全浏览器',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 1586,
#   'W_weibo_id': '2383997393_HC3OaEIAd',
#   'W_search_query': '#垃圾分类#',
#   'W_nick_name': '英宠摄影inpetphoto',
#   'W_weibo_url': 'https://weibo.com/2383997393/HC3OaEIAd',
#   'W_created_at': '2019-07-05T15:09:00',
#   'W_like_num': 263,
#   'W_repost_num': 92,
#   'W_comment_num': 119,
#   'W_content': '上海的伙伴们！我有一个小问题。 听说垃圾分类后狗粑粑是要扔到马桶里冲走的，但装狗粑粑的塑料袋算干垃圾要分类处理[跪了][跪了]是真的么？ 那我买的可降解垃圾袋还有啥用呢[允悲][允悲][允悲] 拉肚子了咋办啊[泪] 我现在好慌，北京马上也要分类了啊#垃圾分类#',
#   'W_user_id': '2383997393',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iPhone X',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '1970-01-01T00:00:02'},
#  {'W_ID': 5949,
#   'W_weibo_id': '2152024140_F9v731iRQ',
#   'W_search_query': ' ',
#   'W_nick_name': '张铭PKUCS',
#   'W_weibo_url': 'https://weibo.com/2152024140/F9v731iRQ',
#   'W_created_at': '2017-06-25T21:52:32',
#   'W_like_num': 12,
#   'W_repost_num': 5,
#   'W_comment_num': 2,
#   'W_content': '北京市理科状元来北大学计算机。八中素质班李宇轩，要来北大计算机系了。“你对于将来有没有规划？现在最心仪哪所学校，为什么？”八中素质班李宇轩答曰 “将来想要写软件；大学想去北大，因为喜欢北大自由开放的学风。” 震惊！小学未上完，竟成了高考状元',
#   'W_user_id': '2152024140',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': 'iOS',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-18T13:21:00'},
#  {'W_ID': 10067,
#   'W_weibo_id': '1937618377_ytuRrbYJ6',
#   'W_search_query': ' ',
#   'W_nick_name': '-林鸿飞-',
#   'W_weibo_url': 'https://weibo.com/1937618377/ytuRrbYJ6',
#   'W_created_at': '2012-07-21T18:50:05',
#   'W_like_num': 0,
#   'W_repost_num': 1,
#   'W_comment_num': 0,
#   'W_content': '地理新发现：季节性海滨城市---帝都。暑假旅游那里去？都到北京看海去。（备注：自备救生用具）',
#   'W_user_id': '1937618377',
#   'W_image_url': 'None',
#   'W_video_url': 'None',
#   'W_tool': '微博 weibo.com',
#   'W_location': 'None',
#   'W_location_map_info': 'None',
#   'W_origin_weibo_url': 'None',
#   'W_origin_weibo_content': 'None',
#   'W_crawl_time': '2019-07-16T14:24:00'}]

# %% [markdown]
# # 客户端对于后端数据接口的访问

# %%
import requests

body = {'wordQuery':'我',
        'textQuery':'垃圾分类',
        'volume':1000}

baseUrl = 'http://10.8.128.205:29280/Lawbda/dataWare/1.0.0/weibo/search'

docs = requests.get(baseUrl,params=body)

# %%
docs.json()[0]
# Out:
# {'C_ID': 70125,
#  'C_comment_id': 'C_4391845553021738',
#  'C_comment_user_id': '6079113604',
#  'C_comment_user_nick_name': '安心的温柔866',
#  'C_content': '#杨洋 垃圾分类# #垃圾分类挑战#  杨洋 垃圾分类  #杨洋[超话]# @杨洋',
#  'C_crawl_time': '1970-01-01T00:00:02',
#  'C_created_at': '2019-07-08T18:17:00',
#  'C_like_num': 1,
#  'C_weibo_url': 'https://weibo.com/1625035922/HCwSG4b6Q'}
